# %%
from sqlalchemy import create_engine
import pandas as pd 
import numpy as np
mysql_setting = {
    'host' : "localhost",
    'dbname': "spider",
    'user': "root",
    'password': ""
}

def getDatabaseConn():
    engine = create_engine('mysql://{user}:{password}@{host}:3306/{dbname}'.format(**mysql_setting), echo=False)
    conn = engine.connect()
    return conn
conn = getDatabaseConn()

# %%
sql_zhilian_position_info = '''
    select company_md5, position_name, salary_low, salary_high, work_year, education, recruit_num from zhilian_position
'''
sql_51job_position_info = '''
    select company_md5, name, salary, education, recruit_num from 51job_position
'''

# %%
sql_zhilian_company_info = '''
    select 
        company_md5, full_name, size, company_nature, industry
    from zhilian_company
'''
sql_51job_company_info = '''
    select 
        company_md5, full_name, size, company_nature, industry
    from 51job_company
'''
zc_df = pd.read_sql(sql_zhilian_company_info, conn)
j5c_df = pd.read_sql(sql_51job_company_info, conn)

# %%
res_zp = pd.merge(zp_df, zc_df, on='company_md5', how='left')
res_j5 = pd.merge(j5_df, j5c_df, on='company_md5', how='left')

# %%
res_zp_g = res_zp.groupby('full_name').size().sort_values(ascending=False).to_frame().rename(columns={0:'position_num'})
pd.concat([zc_df.set_index('full_name'), res_zp_g], axis=1).sort_values('position_num', ascending=False)[:60]
# Out:
#                                              company_md5        size  \
# 上海埃摩森资产管理中心(有限合伙)       25407e8ae336dbbe80cb88c4e9f70163  1000-9999人
# 长春市利嘉商务信息咨询有限公司         f2c9f3fbd25752b4dd75221b358f5246      20-99人
# 弘历软件                    2e2e4af28daafa874a9aea09d7e1529f    500-999人
# 青岛达内软件科技有限公司            76a867b112fdf001049bca919bff51ed  1000-9999人
# 武汉创搜信息技术有限公司            068b45b5d74dc60f614d5c47758796f2    100-499人
# 太平人寿保险有限公司天门支公司         4b1692a4fedac8fee21fc0ad43ad8260    10000人以上
# 上海沃锐商务咨询中心(有限合伙)        7a9748a9934d8dac613c327f42d6b803    500-999人
# 合肥德伟商贸有限公司              ff84246dfb15b85a98ab6d88ebe56a7e    500-999人
# 济南阿甲信息科技有限公司            956a795c807bde285a27ef47f6697658    10000人以上
# 南京达内为上培训学校              ff4a43fdb8188a34ba34efd10f06488f  1000-9999人
# 天津链家宝业房地产经纪有限公司         e4bf4779a1f5411898e6577d739142aa  1000-9999人
# 北京万向联合控股集团有限公司          c297d051b0f75b8c046176dcc506e79c    100-499人
# 武汉易思哲科技有限公司             e20332f77d5ce41808ea557b6c2d3d1d    100-499人
# 德邦物流股份有限公司              996335d8f2d5de6aa40427bed3df6331    10000人以上
# 北京派瑞特网络科技有限公司长春办事处      007e0cb29ce92a0f878216b9e221ebb3  1000-9999人
# 北京万向通汇投资有限公司            247b23fe758de3302744a79444bc96bf    500-999人
# 四川链家房地产经纪有限公司           c8fd44d81ba9cca5b7426451d038a0e0    10000人以上
# 北京才秀人人科技有限公司            8ee36b5fcf55fd53253fe68dc24c75a8  1000-9999人
# 苏州达内信息科技有限公司第一分公司       d6cbbd56ed06785a77dda182ad2b2590  1000-9999人
# 合肥新睿数码科技有限公司            2c056334b6de3ecc2da9419fc66cf89c    10000人以上
# 深圳市正量企业管理顾问有限公司                    合资            基金/证券/期货/投资         596.0
# 重庆易龙盛科技有限公司                     股份制企业               互联网/电子商务         583.0
# 北京才秀人人科技有限公司合肥分公司                上市公司                  计算机软件         578.0
# 皑乐(上海)贸易有限公司                       国企                 贸易/进出口         577.0
# 北京才秀人人科技有限公司太原办事处                上市公司         IT服务(系统/数据/维护)         571.0
# 天津海和蓝图科技有限公司                       民营                  计算机软件         569.0
# 成都文承文化传播有限公司                    股份制企业          媒体/出版/影视/文化传播         552.0
# 中软国际有限公司                         上市公司                  计算机软件         548.0
# 北京旭日东光国际贸易有限公司                   外商独资                 贸易/进出口         536.0
# 重庆市玮庭商贸有限公司                        民营                 贸易/进出口         531.0
# 天软科技集团                          股份制企业               互联网/电子商务         522.0
# 中公教育                               民营               教育/培训/院校         518.0
# 成都高区企业管理有限公司                    股份制企业             通信/电信/网络设备         516.0
# 中软卓越                             上市公司                  计算机软件         501.0
# 成都仁生贸易有限公司                      股份制企业                 贸易/进出口         500.0
# 成都达内科技有限公司武侯分公司                  上市公司                  计算机软件         498.0
# 兰德瑞宝(北京)科技咨询有限公司                   合资            基金/证券/期货/投资         497.0
# 天津天软集团                          股份制企业               互联网/电子商务         495.0
# 上海薄泰贸易有限公司                         合资                 贸易/进出口         484.0
# 中网一号电子商务有限公司                    股份制企业               互联网/电子商务         483.0
# 上海雄山实业有限公司                         民营                  交通/运输         476.0
# 水润科技有限公司                        股份制企业             仪器仪表及工业自动化         473.0
# 北京东方智胜资产管理有限公司                     民营               互联网/电子商务         472.0
# 天津泰鑫展拓科技有限公司                       民营             通信/电信/网络设备         468.0
# 深圳市名瑞德国际金融服务有限公司                股份制企业            基金/证券/期货/投资         458.0

# %%
res_j5_g = res_j5.groupby('full_name').size()
res_j5_g = pd.DataFrame(list(zip(res_j5_g.index, res_j5_g.values))).rename(columns={0:'full_name', 1:"total_recruit_num"})
res_total = pd.merge(j5c_df, res_j5_g, on='full_name', how='left').sort_values('total_recruit_num', ascending=False)[:100]

# %%
sql_we_zhilian = '''
    select salary_low, salary_high, work_year, education from zhilian_position
'''
sql_we_j5 = '''
    select salary, work_year, education from 51job_position
'''
we_zhilian_df = pd.read_sql(sql_we_zhilian, conn)
we_j5_df = pd.read_sql(sql_we_zhilian, conn)

# %%
we_zhilian_g = we_zhilian_df.groupby('work_year')
we_j5_g = we_j5_df.groupby('work_year')

# %%
res_j5_workyear = we_j5_g.size().sort_values(ascending=False)[:7]

# %%
res_j5_workyear.plot(kind='barh', stacked=True)
import matplotlib.pyplot as plt
# 设置中文字体
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False
plt.show()

# %%
sql_lagou_work_year = '''
    select salary, work_year, education from lagou_recruit_day
'''
res_lagou_work_year = pd.read_sql(sql_lagou_work_year, conn)

# %%
res_lagou_work_year.groupby('work_year').size().sort_values(ascending=False)
# Out:
# work_year
# 1-3年     35875
# 不限       24778
# 3-5年     24365
# 5-10年     6839
# 1年以下      2661
# 10年以上      274
# 应届毕业生      249
# 1-3          1
# dtype: int64

# %%
sql_lagou_salary = '''
    select salary, education from lagou_recruit_day
'''
ls_df = pd.read_sql(sql_lagou_salary, conn)
