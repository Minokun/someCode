# %%
from sqlalchemy import create_engine
import pandas as pd 
import numpy as np
mysql_setting = {
    'host' : "localhost",
    'dbname': "spider",
    'user': "root",
    'password': ""
}

def getDatabaseConn():
    engine = create_engine('mysql://{user}:{password}@{host}:3306/{dbname}'.format(**mysql_setting), echo=False)
    conn = engine.connect()
    return conn
conn = getDatabaseConn()

# %%
def salarySplit(line):
    import re
    res = re.match(r'([\d]+)K-([\d]+)K', line)
    if not res:
        res = re.match(r'([\d]+)k-([\d]+)k', line)
    if res:
        salary_low = res[1]
        salary_high = res[2]
        salary_mean = (int(salary_low) + int(salary_high)) / 2
    else:
        res = re.match(r'([\d]+).*', line)
        salary_low = res[1]
        salary_high = res[1]
        salary_mean = res[1]
    return pd.Series([salary_low, salary_high, salary_mean])

sql = '''
    select position_name, position_labels, salary, work_year, education, second_type, city
    from lagou_recruit_day
'''
df_lagou = pd.read_sql(sql, conn)
tmp_lagou = df_lagou['salary'].apply(salarySplit).rename(columns={0:'salary_low', 1:'salary_high', 2:'salary_mean'})
df_lagou = df_lagou.combine_first(tmp_lagou)
df_filter = pd.DataFrame(df_lagou, columns=['salary_high', 'salary_low', 'salary_mean'])

# %% [markdown]
# # 互联网各工作年限薪资分析

# %%
df_lagou[df_lagou.city=='北京'].pivot_table(index=['second_type','work_year']).sort_values('salary_mean',ascending=False)
# Out:
#                               salary_high  salary_low  salary_mean
# second_type        work_year
# 后端开发               10年以上        66.666667   46.666667    56.666667
# 项目管理               10年以上        60.000000   40.000000    50.000000
# [产品设计|需求分析]        5-10年        60.000000   30.000000    45.000000
# 天使投资/VC/PE         5-10年        53.230769   35.846154    44.538462
# 前端开发/移动开发          10年以上        53.333333   33.333333    43.333333
# 管理岗                10年以上        52.222222   33.888889    43.055556
# 并购                 5-10年        50.000000   35.000000    42.500000
# 法务                 10年以上        50.000000   35.000000    42.500000
# 天使投资/VC/PE         10年以上        50.000000   30.000000    40.000000
# [后端开发]             5-10年        50.000000   30.000000    40.000000
# 财务                 10年以上        50.000000   30.000000    40.000000
# [运营|编辑|客服, 运营]     5-10年        50.000000   30.000000    40.000000
# 高端技术职位             5-10年        50.000000   27.500000    38.750000
#                    不限           50.000000   25.000000    37.500000
# 数据开发               5-10年        44.038462   26.134615    35.086538
# 高端产品职位             5-10年        40.000000   30.000000    35.000000
# 生产|加工|制造           5-10年        40.000000   30.000000    35.000000
# [开发|测试|运维类, 后端开发]  3-5年         45.000000   25.000000    35.000000
# 音频视频解码             3-5年         45.000000   22.500000    33.750000
# [产品设计|需求分析]        3-5年         38.750000   27.500000    33.125000
# 软件开发               10年以上        39.600000   26.600000    33.100000
# 客服                 10年以上        40.000000   25.000000    32.500000
# 产品经理-产品            不限           40.000000   25.000000    32.500000
# 国际化产品经理-产品         不限           40.000000   25.000000    32.500000
# 支付产品经理-产品          不限           40.000000   25.000000    32.500000
# 用户研究/需求分析          5-10年        40.000000   25.000000    32.500000
# 策略产品经理-sofa        不限           40.000000   25.000000    32.500000
# 策略架构工程师-sofa       不限           40.000000   25.000000    32.500000
# [前端开发|移动开发]        不限           40.000000   25.000000    32.500000
# PHP开发工程师（北京）- sofa 不限           40.000000   25.000000    32.500000
# ...                                   ...         ...          ...
# 项目管理               1年以下          7.000000    4.000000     5.500000
# 客服                 不限            6.768657    4.179104     5.473881
#                    1年以下          6.705882    4.117647     5.411765
# 审核                 不限            6.444444    4.333333     5.388889
#                    1年以下          6.500000    4.000000     5.250000
# 行政                 1年以下          6.363636    4.090909     5.227273
# 服务业                1年以下          6.000000    4.000000     5.000000
# 贸易|批发|零售|租赁业       1-3年          6.333333    3.666667     5.000000
# 风控                 1年以下          6.000000    4.000000     5.000000
# 供应链                应届毕业生         6.000000    4.000000     5.000000
# 人力资源               1年以下          5.769231    3.846154     4.807692
# 工业设计               1年以下          6.000000    3.000000     4.500000
# 企业软件               不限            6.000000    3.000000     4.500000
# 测试                 应届毕业生         5.000000    4.000000     4.500000
# 运营                 应届毕业生         6.000000    3.000000     4.500000
# 生产|加工|制造           不限            6.000000    3.000000     4.500000
# 人力资源               应届毕业生         5.333333    3.333333     4.333333
# 后端开发               应届毕业生         4.500000    3.500000     4.000000
# 采购                 不限            5.000000    3.000000     4.000000
# 前端开发/移动开发          应届毕业生         4.500000    3.000000     3.750000
# 项目管理               应届毕业生         4.000000    3.000000     3.500000
# 视觉设计/平面设计          应届毕业生         4.000000    3.000000     3.500000
# 文娱|传媒|艺术|体育        1年以下          4.000000    3.000000     3.500000
# 产品经理               应届毕业生         4.000000    2.000000     3.000000
# 前端开发               应届毕业生         3.000000    2.000000     2.500000
# 数据分析               应届毕业生         3.000000    2.000000     2.500000
# 品牌/广告              应届毕业生         3.000000    2.000000     2.500000
# 行政                 应届毕业生         3.000000    2.000000     2.500000
# 证券/期货              5-10年         2.000000    1.000000     1.500000
# 数据开发               应届毕业生         2.000000    1.000000     1.500000
#
# [338 rows x 3 columns]

# %%
sql_51job_position = '''
    select salary, work_year, education, city, industry from 51job_position
'''
df_51job_salary = pd.read_sql(sql_51job_position, conn)

# %%
df_51job_salary = df_51job_salary[df_51job_salary.salary != 'NULL']

# %%
df_51job_salary_deal = df_51job_salary[True ^ df_51job_salary['salary'].str.contains('天|小时|\+')]

# %%
def job51SalaryDeal(line):
    import re
    patten1 = r'([\d]+.?[\d]?)-([\d]+.?[\d]?)千/月'
    patten2 = r'([\d]+.?[\d]?)-([\d]+.?[\d]?)万/月'
    patten3 = r'([\d]+.?[\d]?)-([\d]+.?[\d]?)万/年'
    low = high = mean = 0
    if re.compile(patten1).match(line):
        low = float(re.compile(patten1).match(line).group(1))
        high = float(re.compile(patten1).match(line).group(2))
        mean = int((low + high)) / 2
    elif re.compile(patten2).match(line):
        low = float(re.compile(patten2).match(line).group(1)) * 10
        high = float(re.compile(patten2).match(line).group(2)) * 10
        mean = int((low + high)) / 2
    elif re.compile(patten3).match(line):
        low = float(re.compile(patten3).match(line).group(1)) * 10 / 12
        high = float(re.compile(patten3).match(line).group(2)) * 10 / 12
        mean = int(low + high) / 2
    return pd.Series([round(low, 2), round(high, 2), round(mean, 2)])
df_tmp = df_51job_salary_deal.salary.apply(job51SalaryDeal)
df_tmp.head()
# Out:
#      0     1    2
# 0  4.5   6.0  5.0
# 1  8.0  10.0  9.0
# 2  4.5   6.0  5.0
# 3  4.5   6.0  5.0
# 4  8.0   9.9  8.5

# %%
df_j5_salary = df_51job_salary_deal.combine_first(df_tmp.rename(columns={0 : 'low', 1 : 'high', 2 : 'mean'}))

# %%
df_res = df_j5_salary.groupby('education')['mean'].describe().sort_values(['count'], ascending=False)

# %% [markdown]
# # 整个行业各教育程度薪资情况

# %%
df_res.apply(lambda x: round(x, 2)).rename(index={'NULL': '其他'})
# Out:
#               count   mean     std  min   25%   50%   75%      max
# education
# 大专         985459.0   6.61    5.39  0.0   4.0   5.0   7.5   1250.0
# 其他         840616.0   7.04  106.23  0.0   3.5   5.0   7.5  94999.5
# 本科         387949.0   8.92   11.23  0.0   5.0   7.0  10.0   3750.0
# 高中         183486.0   6.17    4.28  0.0   3.5   5.0   7.0    200.0
# 中专         161956.0   5.53    6.13  0.0   3.5   5.0   7.0   2000.0
# 初中及以下       38349.0   5.98    4.45  0.0   3.5   5.0   7.0    125.0
# 中技          25986.0   5.06    2.88  0.0   3.5   4.5   6.0     85.0
# 硕士          13242.0  11.11   10.18  0.0   6.5   9.0  12.5    295.0
# 博士           1054.0  17.93   20.77  0.0  10.0  14.5  20.5    550.0

# %%
df_j5_salary.head()
# Out:
#   city education  high  industry  low  mean    salary work_year
# 0  张家港        本科   6.0   制药/生物工程  4.5   5.0  4.5-6千/月      3-4年
# 1  张家港        本科  10.0       房地产  8.0   9.0  0.8-1万/月      5-7年
# 2  张家港        中专   6.0       房地产  4.5   5.0  4.5-6千/月      5-7年
# 3  张家港      NULL   6.0    原材料和加工  4.5   5.0  4.5-6千/月         无
# 4  张家港      NULL   9.9  互联网/电子商务  8.0   8.5  8-9.9千/月         无

# %%
df_j5_salary = df_j5_salary[(True ^ df_j5_salary.industry.isin(['1000-5000人', '5000-10000人', '500-1000人', '少于50人', '150-500人', '50-150人']))]
# df_j5_salary.pivot_table(index=['industry'], values=['mean'], columns=['education'], fill_value=0).apply(lambda x: round(x,2))
df_j5_salary_res = df_j5_salary.groupby('industry')['mean'].describe()

# %%
df_j5_industry_salary = df_j5_salary_res[df_j5_salary_res['count'] > 10].sort_values('mean', ascending=False).apply(lambda x:round(x,2))

# %%
pd.DataFrame(df_j5_industry_salary, columns=['mean','std'])
# Out:
#                           mean     std
# industry
# 银行                        9.40    6.38
# 金融/投资/证券                  8.96   17.70
# 房地产                       8.92    8.48
# 租赁服务                      8.61   11.95
# 信托/担保/拍卖/典当               8.47    5.10
# 网络游戏                      8.29    5.38
# 中介服务                      8.04    6.43
# 多元化业务集团公司                 7.82   11.55
# 互联网/电子商务                  7.79  186.36
# 制药/生物工程                   7.76   57.86
# 保险                        7.67    5.34
# 学术/科研                     7.59    7.03
# 计算机软件                     7.09    5.98
# 新能源                       7.09    5.62
# 美容/保健                     6.95    8.32
# 法律                        6.88    5.97
# 采掘业/冶炼                    6.86    4.96
# 航天/航空                     6.86    4.91
# 家居/室内设计/装潢                6.83    5.21
# 专业服务(咨询、人力资源、财会)          6.78   14.48
# 医疗设备/器械                   6.73    5.20
# 通信/电信/网络设备                6.72    5.14
# 电气/电力/水利                  6.71    9.19
# 医疗/护理/卫生                  6.70    7.43
# 建筑/建材/工程                  6.69    9.49
# 家具/家电/玩具/礼品               6.65    5.09
# 石油/化工/矿产/地质               6.60    5.32
# 计算机服务(系统、数据服务、维修)         6.58    5.82
# 仪器仪表/工业自动化                6.57    4.74
# 电子技术/半导体/集成电路             6.53    4.73
# ...                        ...     ...
# 水利水电工程 给排水科学与工程           5.00    0.00
# 市场营销 环境工程                 5.00    0.00
# 计算机工程 软件工程                5.00    0.00
# 计算机工程                     5.00    0.00
# 艺术设计                      5.00    0.00
# 法学 经济法                    5.00    0.00
# 环境工程 环境科学                 5.00    0.00
# 市场营销 工商管理                 5.00    0.00
# 安全工程                      5.00    0.00
# 热能与动力工程 给排水科学与工程          5.00    0.00
# 新闻学 广告学                   5.00    0.00
# 电气工程及其自动化 热能与动力工程         5.00    0.00
# 工程造价管理                    5.00    0.00
# 工程造价管理 工业与民用建筑            5.00    0.00
# 环境工程 园林                   5.00    0.00
# 环境工程 给排水科学与工程             5.00    0.00
# 电子信息工程 软件工程               5.00    0.00
# 环境工程                      4.98    0.18
# 机械设计制造及其自动化               4.95    0.27
# 会计学                       4.92    0.34
# 计算机科学与技术                  4.92    0.34
# 电气工程及其自动化 电力系统及自动化        4.92    0.35
# 市场营销                      4.34    0.76
# 计算机科学与技术 软件工程             3.82    0.64
# 行政管理                      3.59    0.38
# 图书馆学和档案学                  3.50    0.00
# 人力资源管理                    3.50    0.00
# 审计学 会计学                   3.50    0.00
# 新闻学                       3.50    0.00
# 机械设计制造及其自动化 机械电子工程/机电一体化  3.08    0.51
#
# [95 rows x 2 columns]

# %%
sql_zl_position = '''
    select position_name, city, salary_low, salary_high, work_year, education, position_type from zhilian_position
'''
df_zl_position = pd.read_sql(sql_zl_position, conn)

# %% [markdown]
# # 智联北京软件销售岗 工作年限-学历 薪资待遇

# %%
# df_zl_position[(df_zl_position['city']=='北京') & (df_zl_position.position_name.str.contains('软件销售'))].pivot_table(index=['work_year','education']).apply(lambda x:round(x, 2)).rename(columns={'salary_high':'最高薪资', 'salary_low':'最低薪资'})
df_zl_position[(df_zl_position['city']=='北京') & (df_zl_position.position_name.str.contains('软件销售'))].head(30)
# Out:
#                     position_name city  salary_low  salary_high work_year  \
# 91448                      软件销售代表   北京        6001         8000        不限
# 138271                      软件销售员   北京        4001         6000      1-3年
# 138493      腾讯企业办公软件销售代表-老员工均薪10K   北京        8001        10000        不限
# 139121               软件销售经理（政府行业）   北京       10000        20000     5-10年
# 139436                   金融软件销售代表   北京        8001        10000        不限
# 143450          软件销售代表（提供住宿+带薪培训）   北京        4000         8000       无经验
# 144338       软件销售代表（周末双休、五险一金）18A   北京        6001         8000        不限
# 144586           互联网广告/软件销售 （16A）   北京        6001         8000        不限
# 144858           CRM系统办公软件销售（16A)   北京        6000        10000        不限
# 144891         办公软件销售（钉钉CRM系统）16A   北京        5000        10000       无经验
# 145643                    软件销售专员R   北京        5000        10000        不限
# 145801          MT股票软件销售（高薪包住晋升快）   北京        4000         8000      1年以下
# 145806                  金融软件销售 AB   北京       10001        15000        不限
# 146445          软件销售代表（无责底薪+提供住宿）   北京        4000         8000        不限
# 146961               Autodesk软件销售   北京        3500         7000        不限
# 147147                       软件销售   北京        8001        10000        不限
# 147850       会议、直播软件销售（五险一金 各种福利）   北京        4001         6000        不限
# 147932   高级软件销售代表（好福利好待遇五险一金周末双休）   北京        6001         8000      1-3年
# 148007                软件销售（应届毕业生）   北京        5000         7000        不限
# 159497       腾讯办公软件销售（无责底薪+双休+五险）   北京        8001        10000        不限
# 203518  腾讯急聘软件销售 （月均8K+双休+不加班+五险）   北京        6001         8000      1年以下
# 203905                  软件销售大客户经理   北京        8001        10000      3-5年
# 204465                   大区软件销售经理   北京       10001        15000        不限
# 204570                       软件销售   北京        4500         9000        不限
# 204774                  软件销售/腾讯EC   北京        6000        12000        不限
# 243563       腾讯代理软件销售（无责底薪+双休+五险）   北京        6001         8000        不限
# 246299                 软件销售顾问（北京）   北京        4000         7000      1-3年
# 250559                       软件销售   北京        4001         6000        不限
# 299248    阿里巴巴/腾讯企业办公软件销售(编号：18A）   北京        8001        10000        不限
# 300393                  销售专员/软件销售   北京        4001         6000        不限
#
#        education position_type
# 91448         不限       市场专员/助理
# 138271        本科         销售工程师
# 138493        大专          销售代表
# 139121        大专          销售经理
# 139436        大专          销售经理
# 143450        大专          销售代表
# 144338        不限          客户代表
# 144586        大专          客户代表
# 144858        不限       大客户销售代表
# 144891        大专          销售代表
# 145643        大专          销售代表
# 145801        大专          销售代表
# 145806        大专          销售代表
# 146445        大专          销售代表
# 146961        大专          销售代表
# 147147        大专          销售代表
# 147850        大专       大客户销售代表
# 147932        中专       大客户销售代表
# 148007        大专          销售代表
# 159497        大专          销售代表
# 203518        大专          销售代表
# 203905        不限       大客户销售代表
# 204465        本科        区域销售总监
# 204570        不限    渠道/分销经理/主管
# 204774        大专          销售代表
# 243563        大专          销售代表
# 246299        大专         销售工程师
# 250559        大专         销售工程师
# 299248        不限       大客户销售代表
# 300393        不限          销售代表

# %%
df_zl_position.groupby(['position_type']).describe().salary_high.sort_values('50%', ascending=False)[:100]
# Out:
#                   count          mean           std      min      25%  \
# position_type
# CTO/CIO            52.0  44942.288462  28307.452358      0.0  23750.0
# 行长/副行长             44.0  32545.431818  24278.794548      0.0  20000.0
# 首席财务官CFO           62.0  30983.854839  22811.718961      0.0  15000.0
# 银行客户总监             16.0  31000.000000  14787.382009  16000.0  20000.0
# IT技术/研发总监         116.0  27724.137931  18100.966204      0.0  15000.0
# 融资总监              107.0  27579.439252  18301.993593      0.0  15000.0
# IT项目总监             59.0  24203.389831  17275.435681      0.0  15000.0
# 合伙人               197.0  40228.416244  46411.891604      0.0  10000.0
# 算法工程师             326.0  21608.892638  14260.365237      0.0  10000.0
# 办事处首席代表             7.0  25142.857143  21058.874388   6000.0  15000.0
# 副总裁/副总经理          411.0  25672.987835  20881.729259      0.0  12000.0
# 系统架构设计师           381.0  22607.611549  16040.047572      0.0  10000.0
# 分公司/代表处负责人        414.0  23567.743961  19665.227270      0.0  10000.0
# 船长                  3.0  23333.333333   5773.502692  20000.0  20000.0
# 产品总监              116.0  21932.948276  13667.753149      0.0  14250.0
# 咨询总监               78.0  23205.128205  15659.824496      0.0  10000.0
# 首席执行官CEO/总裁/总经理   358.0  29681.564246  26540.352361      0.0  15000.0
# 首席运营官COO           75.0  23720.000000  16515.807334      0.0  15000.0
# 高级建筑工程师/总工        324.0  18959.876543  13545.757609      0.0  10000.0
# 部门/事业部管理          458.0  21459.078603  18264.490525      0.0   8000.0
# 销售总监             2909.0  19564.072877  14893.878477      0.0  10000.0
# 策略发展总监             60.0  19200.000000  11978.511834      0.0  10000.0
# 公关总监               84.0  19107.142857  10206.326714   6000.0  10000.0
# 美容整形科医生            75.0  24633.320000  23111.076066      0.0   6250.0
# 银行经理/主任            32.0  15000.000000  11356.396521      0.0   8000.0
# 生产总监               68.0  17632.352941  10460.878665   6000.0  10000.0
# 技术研发经理/主管          62.0  14645.161290   8454.500740   6000.0   8000.0
# 互联网产品经理/主管       1174.0  17173.506814  10008.028712      0.0  10000.0
# 区域销售总监            770.0  19231.168831  21252.242349      0.0  10000.0
# 证券/投资客户总监         163.0  19981.595092  17742.838024      0.0  10000.0
# ...                 ...           ...           ...      ...      ...
# 房地产项目配套工程师        116.0  12189.655172   8055.150978      0.0   8000.0
# 大客户销售代表          5001.0  10492.909618   6894.540784      0.0   8000.0
# 营运经理              117.0  12452.991453   9590.985105      0.0   6000.0
# 房地产销售主管           218.0  10420.642202   5747.095885      0.0   8000.0
# 股票/期货操盘手         1500.0  11935.999333  10431.986267      0.0   8000.0
# 房地产销售经理           572.0  12359.263986  11015.770069      0.0   8000.0
# 房地产项目管理           362.0  15469.613260  15034.831742      0.0   8000.0
# 房地产项目开发报建         266.0  13295.112782  12001.663980      0.0   7125.0
# 艺术/设计总监           284.0  13036.971831   8798.361917      0.0   6875.0
# 公关经理/主管           322.0  11818.316770   7051.792633      0.0   8000.0
# 船员/水手             382.0  12348.167539   3355.057966   4000.0  10000.0
# 航空乘务               68.0  11382.352941   4926.411948   2000.0   7750.0
# 房地产项目招投标          130.0  12600.000000  11131.072509      0.0   6000.0
# 房地产项目策划经理/主管      524.0  13204.938931   9967.677261      0.0   8000.0
# 射频工程师              49.0  12210.204082   6149.737288   3800.0   8000.0
# 工厂厂长/副厂长          228.0  12638.153509   7115.288281      0.0   8000.0
# 施工队长              102.0  13450.960784  15397.347305      0.0   7000.0
# 汽车底盘/总装工程师         35.0  10657.114286   6379.878824      0.0   7000.0
# 品牌主管               94.0  12178.297872  11741.741242      0.0   6000.0
# 品酒师                 3.0   8666.666667   2309.401077   6000.0   8000.0
# 渠道/分销经理/主管       1540.0  10459.611039   6726.665722      0.0   8000.0
# 校长/副校长           1099.0  13449.499545   7695.002709      0.0   8000.0
# 机械设备经理             46.0  12826.086957  10877.712888      0.0   8000.0
# 医药销售经理/主管         421.0  11791.211401   8899.231840      0.0   6000.0
# 医药招商              153.0  10957.516340   5404.660426      0.0   8000.0
# 珠宝/收藏品鉴定           15.0  15999.933333  23811.509823      0.0   8000.0
# 理财顾问/财务规划师        379.0  10911.878628   6657.082977   4000.0   8000.0
# 瑜伽教练               27.0  15370.370370  10912.759463   2000.0   6000.0
# 瓦工                  5.0  17400.000000  18324.846521   7000.0   8000.0
# 区域销售经理/主管        2806.0  11043.421597   7334.057588      0.0   8000.0
#
#                      50%      75%       max
# position_type
# CTO/CIO          40000.0  70000.0  120000.0
# 行长/副行长           30000.0  50000.0   99999.0
# 首席财务官CFO         30000.0  37500.0  100000.0
# 银行客户总监           30000.0  32500.0   70000.0
# IT技术/研发总监        25000.0  40000.0   80000.0
# 融资总监             20000.0  40000.0  100000.0
# IT项目总监           20000.0  30000.0   70000.0
# 合伙人              20000.0  50000.0  150000.0
# 算法工程师            20000.0  30000.0   80000.0
# 办事处首席代表          20000.0  25000.0   70000.0
# 副总裁/副总经理         20000.0  30000.0  140000.0
# 系统架构设计师          20000.0  30000.0  100000.0
# 分公司/代表处负责人       20000.0  30000.0  150000.0
# 船长               20000.0  25000.0   30000.0
# 产品总监             20000.0  30000.0   70000.0
# 咨询总监             20000.0  30000.0   70000.0
# 首席执行官CEO/总裁/总经理  20000.0  50000.0  150000.0
# 首席运营官COO         20000.0  30000.0  100000.0
# 高级建筑工程师/总工       15000.0  20000.0  100000.0
# 部门/事业部管理         15000.0  30000.0  100000.0
# 销售总监             15000.0  20000.0  150000.0
# 策略发展总监           15000.0  30000.0   50000.0
# 公关总监             15000.0  30000.0   50000.0
# 美容整形科医生          15000.0  45000.0   99999.0
# 银行经理/主任          15000.0  20000.0   50000.0
# 生产总监             15000.0  20000.0   70000.0
# 技术研发经理/主管        15000.0  15000.0   40000.0
# 互联网产品经理/主管       15000.0  20000.0  100000.0
# 区域销售总监           15000.0  20000.0  150000.0
# 证券/投资客户总监        15000.0  20000.0  100000.0
# ...                  ...      ...       ...
# 房地产项目配套工程师       10000.0  15000.0   70000.0
# 大客户销售代表          10000.0  12000.0  120000.0
# 营运经理             10000.0  15000.0   50000.0
# 房地产销售主管          10000.0  15000.0   50000.0
# 股票/期货操盘手         10000.0  15000.0  150000.0
# 房地产销售经理          10000.0  15000.0  150000.0
# 房地产项目管理          10000.0  20000.0  100000.0
# 房地产项目开发报建        10000.0  15000.0   70000.0
# 艺术/设计总监          10000.0  15000.0   80000.0
# 公关经理/主管          10000.0  15000.0   50000.0
# 船员/水手            10000.0  15000.0   50000.0
# 航空乘务             10000.0  15000.0   30000.0
# 房地产项目招投标         10000.0  15000.0   70000.0
# 房地产项目策划经理/主管     10000.0  15000.0  100000.0
# 射频工程师            10000.0  15000.0   30000.0
# 工厂厂长/副厂长         10000.0  15000.0   50000.0
# 施工队长             10000.0  15000.0   99999.0
# 汽车底盘/总装工程师       10000.0  15000.0   30000.0
# 品牌主管             10000.0  14500.0  100000.0
# 品酒师              10000.0  10000.0   10000.0
# 渠道/分销经理/主管       10000.0  12000.0  100000.0
# 校长/副校长           10000.0  15000.0  100000.0
# 机械设备经理           10000.0  15000.0   70000.0
# 医药销售经理/主管        10000.0  15000.0  100000.0
# 医药招商             10000.0  15000.0   30000.0
# 珠宝/收藏品鉴定         10000.0  12500.0   99999.0
# 理财顾问/财务规划师       10000.0  12000.0   80000.0
# 瑜伽教练             10000.0  30000.0   30000.0
# 瓦工               10000.0  12000.0   50000.0
# 区域销售经理/主管        10000.0  14000.0  100000.0
#
# [100 rows x 8 columns]

# %%
df_city_salary_res = df_j5_salary.groupby('city')['mean'].describe().apply(lambda x:round(x,2))
pd.DataFrame(df_city_salary_res[df_city_salary_res['count'] > 5], columns=['std','mean','50%']).sort_values('mean',ascending=False).rename(columns={'std':'标准差','mean':'平均值','50%':'中位数'})
# Out:
#          标准差    平均值   中位数
# city
# 温州    780.70  13.96  6.00
# 北京      9.29   9.70  7.00
# 上海      5.63   8.71  7.00
# 杭州     19.15   8.38  7.00
# 深圳      5.99   8.19  7.00
# 赤峰     13.93   8.08  5.00
# 衢州     11.36   8.03  6.00
# 东营     10.74   7.97  6.00
# 佛山      8.29   7.97  5.00
# 濮阳      6.86   7.83  7.00
# 西宁      8.67   7.78  6.00
# 珠海     10.52   7.78  6.00
# 乐山     10.10   7.73  6.00
# 安阳      8.48   7.70  6.00
# 达州      8.76   7.69  6.00
# 怀化     20.58   7.69  5.50
# 金华     18.37   7.66  5.50
# 十堰     16.19   7.66  5.50
# 南京      7.77   7.65  7.00
# 眉山     13.71   7.65  5.00
# 内江     12.43   7.62  5.50
# 广安     12.21   7.60  5.50
# 宜宾     10.62   7.60  6.00
# 汕尾      7.24   7.59  5.50
# 广州      5.31   7.57  7.00
# 滨州     10.27   7.57  5.50
# 台州      7.80   7.55  6.00
# 宁德     12.35   7.52  5.50
# 绍兴      7.77   7.52  6.00
# 运城      7.36   7.48  5.00
# ...      ...    ...   ...
# 昆明      6.17   6.33  5.00
# 徐州      8.07   6.30  5.00
# 清远      6.37   6.29  5.00
# 洛阳      5.87   6.28  5.00
# 江门      5.37   6.27  5.00
# 吉安      4.98   6.23  5.00
# 柳州      8.68   6.21  5.00
# 湛江      8.24   6.20  5.00
# 邢台      5.80   6.20  5.00
# 保定      6.14   6.19  5.00
# 肇庆      5.60   6.17  5.00
# 鄂州      6.23   6.16  4.50
# 孝感      7.12   6.16  5.00
# 天津     19.07   6.15  5.00
# 渭南      6.01   6.15  5.00
# 丹东      5.83   6.14  5.00
# 咸宁      5.94   6.10  5.00
# 西安     16.62   6.10  5.00
# 芜湖      4.80   6.04  5.00
# 黄冈      4.40   6.01  5.00
# 邯郸      3.61   5.95  4.75
# 大连     22.38   5.84  4.50
# 兰州      2.52   5.76  5.00
# 鞍山      5.56   5.70  5.00
# 咸阳      5.38   5.68  5.00
# 阜阳      2.56   5.53  5.00
# 沈阳     18.35   5.52  4.50
# 哈尔滨    25.31   5.47  4.50
# 长春     25.99   5.22  3.50
# 开封      1.69   4.75  4.25
#
# [183 rows x 3 columns]

# %%
city_mix_df = pd.concat([pd.DataFrame(df_j5_salary, columns=['city', 'salary_mean', 'work_year']),pd.DataFrame(df_lagou, columns=['city', 'salary_mean', 'work_year'])])
g_df = city_mix_df[city_mix_df['work_year'] == '1-3年'].groupby('city')

# %% [markdown]
# # 90后在国内城市岗位薪资排行

# %%
g_df_res = g_df.describe().apply(lambda x:round(x,3))
g_df_res = g_df_res[(g_df_res[('salary_mean','std')]<20) & (g_df_res[('salary_mean','count')]>18)].sort_values(('salary_mean','mean'),ascending=False)
pd.DataFrame(g_df_res, columns=[('salary_mean','std'),('salary_mean','mean'),('salary_mean','50%')]).rename(columns={'salary_mean':'薪资/k','mean':'平均数','std':'标准差','50%':'中位数',})
# Out:
#        薪资/k
#         标准差     平均数    中位数
# city
# 北京    6.249  12.212  11.00
# 上海    4.976  10.640   9.00
# 杭州    5.072  10.383   9.00
# 深圳    4.640   9.668   8.50
# 南京    3.892   8.513   7.50
# 广州    3.631   8.425   7.50
# 珠海    4.054   8.332   7.50
# 苏州    3.804   8.314   7.50
# 厦门    3.528   8.011   7.50
# 宁波    2.846   7.821   7.50
# 福州    2.994   7.614   7.50
# 武汉    3.379   7.534   7.00
# 成都    3.507   7.472   6.50
# 无锡    3.448   7.468   7.00
# 东莞    3.157   7.388   7.00
# 金华    4.086   7.352   7.00
# 合肥    3.364   7.305   6.50
# 天津    3.315   7.240   6.50
# 贵阳    2.683   7.234   6.50
# 温州    2.636   7.213   7.00
# 廊坊    2.530   7.148   7.00
# 乌鲁木齐  2.668   7.051   6.50
# 长沙    3.110   7.032   6.50
# 绵阳    2.199   6.969   6.75
# 南通    4.000   6.964   6.00
# 中山    2.840   6.957   6.00
# 重庆    3.143   6.922   6.00
# 嘉兴    2.409   6.881   6.25
# 济南    2.556   6.841   6.50
# 青岛    2.722   6.808   6.00
# 郑州    2.838   6.680   6.00
# 呼和浩特  4.417   6.638   5.75
# 大连    2.728   6.532   6.00
# 石家庄   3.072   6.512   6.00
# 西安    2.927   6.500   6.00
# 沈阳    2.799   6.475   6.00
# 南宁    2.543   6.439   6.00
# 临沂    2.585   6.403   6.00
# 常州    2.199   6.365   6.00
# 惠州    2.411   6.280   6.00
# 泉州    2.084   6.192   6.00
# 南昌    2.748   6.185   6.00
# 银川    2.007   6.136   6.00
# 绍兴    1.629   6.107   6.00
# 潍坊    1.752   6.000   6.00
# 哈尔滨   2.231   5.866   5.00
# 烟台    1.788   5.858   6.00
# 太原    2.248   5.839   5.50
# 汕头    2.717   5.717   5.00
# 扬州    2.345   5.712   5.00
# 长春    2.315   5.704   5.00
# 桂林    1.833   5.621   6.00
# 保定    2.004   5.593   5.00
# 徐州    1.584   5.586   5.50
# 唐山    1.531   5.431   6.00

# %% [markdown]
# # 拉钩销售 职位-工作年限 薪资水平/K

# %%
sale_df = df_lagou[(df_lagou.city=='北京') & (df_lagou.position_name.str.contains('软件销售'))].pivot_table(index=['work_year', 'education']).apply(lambda x: round(x, 2)).rename(columns={'salary_high':'最高薪资', 'salary_low':'最低薪资','salary_mean':'平均薪资'})
sale_df
# Out:
#                      最高薪资  最低薪资   平均薪资
# work_year education
# 1-3年      大专         13.0   7.0  10.00
# 3-5年      大专         10.0   6.0   8.00
# 不限        不限          8.0   4.0   6.00
#           大专          9.5   6.0   7.75
#           本科          8.0   4.0   6.00

# %%
# 读取51job
j5_df = pd.read_hdf('/Users/monstar/Desktop/ProjectCode/bigdatarecruit/DataMining/salaryWE.h5')
j5_df[(j5_df.city == '北京') & (j5_df['name'].str.contains('软件销售'))].pivot_table(index=['work_year', 'education']).apply(lambda x: round(x, 2)).rename(columns={'high':'最高薪资', 'low':'最低薪资','mean':'平均薪资'})
# Out:
#                       最高薪资   最低薪资   平均薪资
# work_year education
# 1年        NULL        6.00   4.50   5.00
#           中专          8.00   6.00   7.00
#           大专         13.57   9.00  11.25
#           本科          8.00   5.00   6.50
#           高中         13.46   8.67  11.06
# 2年        NULL       12.00   6.00   9.00
#           中专         20.00  15.00  17.50
#           大专         18.83  14.12  16.47
#           本科         12.67   9.67  11.17
# 3-4年      NULL       25.00  16.67  20.50
#           大专         17.09  12.91  15.00
#           本科         12.67   8.00  10.33
# 5-7年      大专         15.00  10.00  12.50
# 8-9年      大专         25.00  15.00  20.00
#           本科         20.00  15.00  17.50
# 无         NULL       10.21   6.88   8.54
#           中专          5.62   3.50   4.50
#           大专          9.60   6.58   8.08
#           本科          8.60   6.20   7.30
#           硕士         10.00   8.00   9.00
#           高中          8.00   5.43   6.64

# %%
j5_df[(j5_df.city == '北京') & (j5_df['name'].str.contains('软件销售'))].head(30)
# Out:
#         city education  high           industry   low  mean  \
# 3407061   北京        大专   8.0  计算机服务(系统、数据服务、维修)   6.0   7.0
# 3407287   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3409298   北京      NULL  10.0           互联网/电子商务   5.0   7.5
# 3410387   北京        大专  10.0              计算机软件   5.0   7.5
# 3410909   北京      NULL  10.0         通信/电信/网络设备   7.0   8.5
# 3412048   北京        大专   8.0           互联网/电子商务   6.0   7.0
# 3413280   北京        中专   0.0              计算机软件   0.0   0.0
# 3414306   北京        大专  25.0              计算机软件  15.0  20.0
# 3414307   北京        大专  15.0              计算机软件  10.0  12.5
# 3416697   北京        大专  20.0              计算机软件  15.0  17.5
# 3417091   北京        本科  10.0              计算机软件   5.0   7.5
# 3418450   北京        大专   8.0              计算机软件   4.0   6.0
# 3418857   北京      NULL  10.0              计算机软件   5.0   7.5
# 3420023   北京      NULL  12.0              计算机软件   6.0   9.0
# 3420497   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420524   北京        大专   8.0           互联网/电子商务   6.0   7.0
# 3420820   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420825   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420838   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420841   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420849   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420852   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420857   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420945   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420952   北京        大专   8.0           互联网/电子商务   6.0   7.0
# 3420954   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3420969   北京        大专   8.0           互联网/电子商务   6.0   7.0
# 3420981   北京        高中  15.0           互联网/电子商务  10.0  12.5
# 3420983   北京        大专  20.0           互联网/电子商务  15.0  17.5
# 3421788   北京        本科   8.0  计算机服务(系统、数据服务、维修)   6.0   7.0
#
#                                  name      salary work_year
# 3407061      软件销售（试用期无责3700+五险+双休+住宿）      6-8千/月         无
# 3407287    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3409298                 软件销售（工作地点在燕郊）    0.5-1万/月         无
# 3410387                          软件销售    0.5-1万/月        1年
# 3410909                          软件销售    0.7-1万/月         无
# 3412048      软件销售代表（0经验，双休，保底4000，社保）      6-8千/月         无
# 3413280                        软件销售专员      2万以下/年         无
# 3414306                工业软件销售经理（GYSY）  1.5-2.5万/月      8-9年
# 3414307               工业软件销售工程师（GYSY）    1-1.5万/月      5-7年
# 3416697                      医疗软件销售经理    1.5-2万/月         无
# 3417091                        软件销售专员    0.5-1万/月        1年
# 3418450                        OA软件销售      4-8千/月         无
# 3418857                    软件销售代表（北京）    0.5-1万/月         无
# 3420023        软件销售/大客户销售(SAAS平台业务方向）  0.6-1.2万/月        2年
# 3420497    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420524      软件销售代表（0经验，双休，保底4000，社保）      6-8千/月         无
# 3420820    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420825    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420838    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420841    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420849    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420852    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420857  高级企业软件销售代表（无责底薪8000+高额提成+社保）    1.5-2万/月      3-4年
# 3420945    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        2年
# 3420952      软件销售代表（0经验，双休，保底4000，社保）      6-8千/月         无
# 3420954    企业软件销售代表（无责底薪4000+高额提成+社保）    1.5-2万/月        1年
# 3420969      软件销售代表（0经验，双休，保底4000，社保）      6-8千/月         无
# 3420981      软件销售代表（0经验，双休，保底4000，社保）    1-1.5万/月        1年
# 3420983    企业软件销售代表（无责底薪4500+高额提成+社保）    1.5-2万/月        2年
# 3421788                      医疗软件销售经理      6-8千/月      3-4年
