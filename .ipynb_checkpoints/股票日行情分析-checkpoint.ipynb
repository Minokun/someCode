# %%
import tushare as ts
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['KaiTi']
plt.rcParams['axes.unicode_minus'] = False
ts.set_token('5f74ec7e9d0e71e8b8174fc48550635013e084a53d63af4cac832ab3')
pro = ts.pro_api()

# %%
data = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')

# %%
data[data['name'].isin(['永鼎股份', '招商轮船', '中兵红箭', '大名城'])]
# Out:
#         ts_code  symbol  name area industry list_date
# 113   000519.SZ  000519  中兵红箭   湖南     矿物制品  19931008
# 2251  600094.SH  600094   大名城   上海     区域地产  19970703
# 2261  600105.SH  600105  永鼎股份   江苏     通信设备  19970929
# 3141  601872.SH  601872  招商轮船   上海       水运  20061201

# %%
import time
from datetime import datetime 
today = datetime.now().strftime("%Y%m%d")
today
# Out:
# '20191126'

# %%
def getTR(row):
    return max(abs(float(row['high']) - float(row['low'])), abs(float(row['high']) - float(row['pre_close'])), abs(float(row['low']) - float(row['pre_close'])))

def getTRRatio(row):
    return round(abs(row['TR'] /  float(row['pre_close'])) * 100, 2)

# %%
import seaborn as sns
sns.set()

# %%
def showRes(df, title, days=14):

    df['TR'] = df.apply(lambda row: getTR(row), axis = 1)
    df['TRP'] = df.apply(lambda row: getTRRatio(row), axis = 1)
    df['ATR'] = round(df['TR'].rolling(window=days).mean(), 2)
    df_deal = df[df['ATR'] > 0]
    df_deal.head()
    
    plt.figure(figsize=(16, 12))
    
    plt.title(title)
    
    #添加标签
    for a, b in list(zip(df_deal['trade_date'], df_deal['pct_chg'])):
        plt.text(a, b + 0.5 * (-1 if b <= 0 else 1), str(b), ha='center', va='bottom')
        
    x = df_deal['trade_date'].values
    y1 = df_deal['TR'].values
    y2 = df_deal['close'].values
    y3 = df_deal['ATR'].values
    y4 = df_deal['pct_chg'].values
    
    plt.plot(x, y1, label='TR')
    plt.plot(x, y2, label='close')
    plt.plot(x, y3, label='ATR')
    plt.bar(x, y4, label='pct_chg')
    plt.xticks(rotation=70)
    plt.legend()
    return df_deal

df1 = pro.daily(ts_code='601872.SH', start_date='20190201', end_date=today)[::-1]
df1_deal = showRes(df1, '601872.SH', days=14)
df1_deal
# Out:
#        ts_code trade_date  open  high   low  close  pre_close  change  \
# 182  601872.SH   20190227  4.62  4.72  4.57   4.58       4.66   -0.08
# 181  601872.SH   20190228  4.61  4.77  4.57   4.61       4.58    0.03
# 180  601872.SH   20190301  4.61  4.68  4.58   4.67       4.61    0.06
# 179  601872.SH   20190304  4.70  4.80  4.61   4.68       4.67    0.01
# 178  601872.SH   20190305  4.66  4.74  4.61   4.72       4.68    0.04
# 177  601872.SH   20190306  4.71  4.78  4.70   4.78       4.72    0.06
# 176  601872.SH   20190307  4.75  4.92  4.72   4.84       4.78    0.06
# 175  601872.SH   20190308  4.75  4.76  4.51   4.52       4.84   -0.32
# 174  601872.SH   20190311  4.52  4.71  4.52   4.67       4.52    0.15
# 154   1.3699   227567.14   117719.105  0.12   2.35  0.19
# 153  -0.3861   239512.07   122494.699  0.17   3.28  0.20
# ..       ...         ...          ...   ...    ...   ...
# 29   -0.5682  3269664.31  2338393.685  0.68   9.66  0.37
# 28   -5.8571  2781927.52  1897547.327  0.85  12.14  0.42
# 27   -8.0425  3038643.15  1905921.698  0.67  10.17  0.46
# 26   -1.8152  1810289.22  1088774.803  0.31   5.12  0.47
# 25   -2.6891  1340541.05   776184.554  0.27   4.54  0.49
# 24    0.6908  1211310.68   700758.978  0.16   2.76  0.48
# 23   -3.0875   938403.90   535496.293  0.19   3.26  0.47
# 22    0.0000   870024.44   500099.302  0.19   3.36  0.45
# 21    0.0000   936949.68   526521.555  0.29   5.13  0.44
# 20   -1.2389   843853.72   468062.526  0.17   3.01  0.42
# 19   -0.8961   934647.72   515230.713  0.26   4.66  0.41
# 18   -3.0741   590331.18   321024.229  0.20   3.62  0.39
# 17    2.7985   995097.65   544358.389  0.28   5.22  0.37
# 16   -0.3630   408265.58   222845.233  0.11   2.00  0.33
# 15    3.8251   787503.04   443978.974  0.23   4.19  0.30
# 14   -0.3509   452200.29   256226.101  0.12   2.11  0.25
# 13   -4.5775   542039.13   298872.712  0.27   4.75  0.22
# 12   -0.9225   523277.21   279307.245  0.16   2.95  0.21
# 11    0.3724   505338.70   275242.495  0.20   3.72  0.20
# 10    1.2987   567740.50   311122.294  0.23   4.27  0.21
# 9     0.5495   448907.27   248800.832  0.18   3.30  0.21
# 8     2.0036   457138.41   256247.315  0.19   3.46  0.21
# 7    -1.0714   372150.84   206292.314  0.22   3.93  0.20
# 6     6.4982   862355.26   497838.901  0.44   7.94  0.22
# 5     1.0169   627261.32   371989.824  0.27   4.58  0.22
# 4    -0.1678   440548.85   261381.578  0.16   2.68  0.22
# 3     0.5042   704783.11   430753.317  0.34   5.71  0.22
# 2     5.3512   724672.72   450473.923  0.37   6.19  0.24
# 1    -2.5397   669183.26   414600.168  0.29   4.60  0.25
# 0     5.5375   834193.37   532782.955  0.41   6.68  0.27
#
# [183 rows x 14 columns]

# %%
# 0.4
df_real = ts.get_realtime_quotes('601872')[['code','name', 'price','bid','ask','volume','amount','time', 'pre_close', 'high', 'low']]
df_real['TR'] = df_real.apply(lambda row: getTR(row), axis = 1)
df_real
# Out:
#      code  name  price    bid    ask    volume         amount      time  \
# 0  601872  招商轮船  6.450  6.450  6.460  33189798  214205684.000  11:14:17
#
#   pre_close   high    low    TR
# 0     6.480  6.570  6.350  0.22

# %%
df1_deal[(df1_deal['pre_close'] > 5) & (df1_deal['pre_close'] < 7)].plot(figsize=(14, 8), kind='scatter', x='TRP', y='vol')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.set(style="darkgrid")

sns.jointplot("TR", "vol", data=df1_deal[(df1_deal['pre_close'] > 5) & (df1_deal['pre_close'] < 7)], kind="reg",
                  xlim=(0, 0.6), ylim=(0, 1000000), color="m", height=7)
