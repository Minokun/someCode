# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)
for i in range(10):
    plt.plot(x * i, y, label='sin(pi*{})'.format(i))
plt.xlabel('x')
plt.grid()
# 样例显示
plt.legend()

# %%
figure, ax = plt.subplots(2, 2)
ax[0][0].plot(x, y)
ax[0][1].plot(x, y ** 3)
ax[1][0].plot(x, y ** 31)
ax[1][1].plot(x, y ** 8)

# %%
# figure, ax = plt.subplots(2, 1)
s1 = pd.Series(np.random.randn(100).cumsum())
s2 = s1.apply(lambda x: x + 1)
s1[0:20].plot(kind='bar', grid=True, label='s1', title='this is series')
s2[0:20].plot(kind='line', grid=True, label='s2', style='y--')
plt.legend()

# %%
sns.set()
figure, ax = plt.subplots(2, 1)
s1 = pd.Series(np.random.randn(100).cumsum())
s2 = s1.apply(lambda x: x + 1)
s1[0:20].plot(kind='bar', grid=True, label='s1', title='this is series', style='--', ax=ax[0])
s2[0:20].plot(kind='line', grid=True, label='s2', style='y--', ax=ax[1])
plt.legend()

# %%
df = pd.DataFrame(
    np.random.randint(1, 10 , 40).reshape(10, 4),
    columns=['A', 'B', 'C', 'D']
)
df.plot()

# %%
df[:10].plot(kind='bar')

# %%
df.plot(kind='barh')

# %%
df.plot(kind='bar', stacked=True, grid=True)

# %%
sns.set_palette(sns.color_palette('muted'))
df.plot(kind='area', stacked=True, grid=True)

# %% [markdown]
# ## 分布直方图

# %%
plt.hist(s1, rwidth=0.8, bins=15 )
# Out:
# (array([  3.,   3.,   8.,  21.,  12.,   6.,   5.,   6.,   1.,   6.,   5.,
#           5.,  10.,   5.,   4.]),
#  array([-9.90062879, -9.07063259, -8.24063639, -7.41064019, -6.58064399,
#         -5.75064778, -4.92065158, -4.09065538, -3.26065918, -2.43066298,
#         -1.60066678, -0.77067058,  0.05932562,  0.88932182,  1.71931802,
#          2.54931422]),
#  <a list of 15 Patch objects>)

# %%
s1.plot(kind='kde')

# %%
import seaborn as sns

# %%
sns.distplot(s1, hist=True, kde=True, rug=True, bins=20)

# %%
sns.kdeplot(s1, shade=True)

# %%
df = sns.load_dataset('flights')
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df_deal = df.pivot_table(index=['month'], columns='year', values='passengers')
df_deal
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(df_deal, annot=True, fmt='d')

# %%
s = df_deal.sum()
s.values
sns.barplot(x=s.index, y=s.values)
plt.grid()

# %%
x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = np.sin(x+2)*1.25

# %%
def sinplot():
    plt.plot(x, y1)
    plt.plot(x, y2)

# %% [markdown]
# ## 设置背景主题

# %%
style = ['darkgrid', 'dark', 'whitegrid', 'white', 'ticks']
sns.set_style('darkgrid')
sinplot()

# %%
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': 'white',
#  'axes.facecolor': '#EAEAF2',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 0.0,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': 'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.major.size': 0.0,
#  'xtick.minor.size': 0.0,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.major.size': 0.0,
#  'ytick.minor.size': 0.0}

# %% [markdown]
# # 字体大小和网格线粗细设置

# %%
# 线条大小
context=['paper', 'notebook', 'talk', 'poster']
sns.set_context("talk", font_scale=1, rc={'grid.linewidth': 1.5})
sinplot()

# %% [markdown]
# ## 调色板

# %%
sns.palplot(sns.color_palette())
# 调色板样式 
pal_style = ['deep', 'muted', 'pastel', 'bright', 'dark', 'colorblind']

# %%
sns.palplot(sns.color_palette(pal_style[5]))

# %%
# 生成自定义色板
sns.palplot(sns.color_palette('hls', 8))

# %%
# 应用生成色板
sns.set_palette(sns.color_palette('hls',8))
sinplot()

# %%
from string import ascii_letters
# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
